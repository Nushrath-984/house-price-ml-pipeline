# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
batch_loss = np.load("../results/batch_loss.npy")
sgd_loss = np.load("../results/sgd_loss.npy")
minibatch_loss = np.load("../results/minibatch_loss.npy")
comparison = pd.read_csv("../results/week3_comparison.csv")

# %%
print("Week 3 Comparison Table:")
print(comparison.head())
# Out:
# Week 3 Comparison Table:
#          Variant    Final Loss                 Speed    Stability  \
# 0       Batch GD  4.864520e+09   Slow (full dataset)         High
# 1            SGD  4.742935e+09     Fast (per sample)  Low (noisy)
# 2  Mini-Batch GD  2.560636e+12  Moderate (per batch)       Medium
#
#         Accuracy
# 0  Good baseline
# 1     Fluctuates
# 2       Balanced

# %%
plt.figure(figsize=(10,6))
plt.plot(batch_loss, label="Batch GD")
plt.plot(sgd_loss, label="SGD")
plt.plot(minibatch_loss, label="Mini-Batch GD")
plt.xlabel("Epochs")
plt.ylabel("MSE")
plt.title("Week 3 Results: GD Variants")
plt.legend()
plt.grid(True)
plt.show()
