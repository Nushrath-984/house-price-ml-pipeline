# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
y_test = np.load('../results/y_test.npy')
y_pred_linreg = np.load('../results/y_pred_linreg.npy')
y_pred_nn = np.load('../results/y_pred_nn.npy')

print("Files loaded successfully!")
# Out:
# Files loaded successfully!

# %%
os.makedirs('../results/plots', exist_ok=True)

print("Plots folder ready!")
# Out:
# Plots folder ready!

# %%
y_test_flat = y_test.flatten()
y_pred_linreg_flat = y_pred_linreg.flatten()

residuals_lr = y_test_flat - y_pred_linreg_flat

print("Residuals shape:", residuals_lr.shape)
# Out:
# Residuals shape: (15967,)

# %%
plt.figure(figsize=(8,5))

plt.scatter(y_pred_linreg_flat, residuals_lr, alpha=0.6)

plt.axhline(y=0, linestyle='--')

plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot - Linear Regression')

plt.grid(True)

plt.savefig('../results/plots/residual_plot_linreg.png')

plt.show()

# %%
y_pred_nn_flat = y_pred_nn.flatten()

residuals_nn = y_test_flat - y_pred_nn_flat

print("Neural Network Residuals Shape:", residuals_nn.shape)
# Out:
# Neural Network Residuals Shape: (15967,)

# %%
plt.figure(figsize=(8,5))

plt.scatter(y_pred_nn_flat, residuals_nn, alpha=0.6)

plt.axhline(y=0, linestyle='--')

plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot - Neural Network')

plt.grid(True)

plt.savefig('../results/plots/residual_plot_nn.png')

plt.show()

print("Neural Network plot saved!")
# Out:
# Neural Network plot saved!

# %%
plt.figure(figsize=(8,5))

plt.hist(residuals_lr, bins=30, alpha=0.6, label='Linear Regression')
plt.hist(residuals_nn, bins=30, alpha=0.6, label='Neural Network')

plt.xlabel('Residual Error')
plt.ylabel('Frequency')
plt.title('Residual Error Distribution')

plt.legend()

plt.savefig('../results/plots/residual_comparison.png')

plt.show()

print("Comparison plot saved!")
# Out:
# Comparison plot saved!

# %%
print("Week 6 Member 3 Visualization Completed")

print("\nGenerated Files:")
print("1. residual_plot_linreg.png")
print("2. residual_plot_nn.png")
print("3. residual_comparison.png")
# Out:
# Week 6 Member 3 Visualization Completed
#
# Generated Files:
# 1. residual_plot_linreg.png
# 2. residual_plot_nn.png
# 3. residual_comparison.png
